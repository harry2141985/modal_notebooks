# %% [markdown]
# # **Clone**

# %%
# %cd /root
# !git clone https://github.com/harry2141985/MoCha.git
# %cd MoCha

# %% [markdown]
# # **Requirements**

# %% [markdown]
# !pip install -r requirements.txt

# %% [markdown]
# # **FFMPEG**

# %%
# !apt-get update
# !apt-get install -y libjpeg-dev zlib1g-dev libpng-dev
# !apt-get install -y libgl1
# !apt-get install -y libglib2.0-0 libgl1
# !apt-get install -y ffmpeg

# %% [markdown]
# # **Download Models**

# %%
# Create checkpoints folder if it doesn't exist
# !mkdir -p /root/MoCha/checkpoints

# Go to checkpoints folder
# %cd /root/MoCha/checkpoints

# Install huggingface-cli if missing
# !pip install -q huggingface_hub

# Download Wan 2.1 T2V model
# !huggingface-cli download Wan-AI/Wan2.1-T2V-14B --include "*" --local-dir .

# Download MoCha preview model (Orange-3DV-Team/MoCha/preview)
# !huggingface-cli download Orange-3DV-Team/MoCha --include "preview/*" --local-dir .

# !echo "All models downloaded into /root/MoCha/checkpoints"

# %% [markdown]
# # **Main Code**

# %%
# !python /root/MoCha/inference_mocha.py --data_path /root/MoCha/data/test_data.csv
