# %% [markdown]
# # **Clone**

# %%
# %cd /root
# !git clone https://huggingface.co/spaces/tori29umai/Qwen-Image-2509-MultipleAngles
# %cd Qwen-Image-2509-MultipleAngles

# %% [markdown]
# # **Requirements**

# %%
# !pip install -r requirements.txt
# !pip install spaces

# %% [markdown]
# # **FFMPEG**

# %%
# !apt-get update
# !apt-get install -y libglib2.0-0 libgl1
# !apt-get update
# !apt-get install -y ffmpeg

# %% [markdown]
# # **Change in App File**

# %%
# Update the last line of the script to use share=True
file_path = "app.py"   # change if your file name is different

with open(file_path, "r") as f:
    content = f.read()

# Replace demo.launch() with demo.launch(share=True)
updated = content.replace("demo.launch()", "demo.launch(share=True)")

with open(file_path, "w") as f:
    f.write(updated)

print("✅ Updated successfully: demo.launch(share=True)")
# Out:
# ✅ Updated successfully: demo.launch(share=True)

# %% [markdown]
# # **Main Code**

# %%
# !python app.py
