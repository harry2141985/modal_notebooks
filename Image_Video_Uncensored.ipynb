# %% [markdown]
# # **Clone**

# %%
# %cd /root
# !git clone https://github.com/harry2141985/Image-to-Video-Uncensored.git
# %cd Image-to-Video-Uncensored

# %% [markdown]
# # **Requirements**

# %% [markdown]
# !pip install -r requirements.txt

# %% [markdown]
# # **FFMPEG**

# %%
# !apt-get -y update
# !apt-get install -y libglib2.0-0 libgl1
# !apt-get install -y ffmpeg

# %% [markdown]
# # **Main Code**

# %%
# !python app.py
