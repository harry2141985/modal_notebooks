# %% [markdown]
# # **Clone**

# %%
# %cd /root
# !git clone https://huggingface.co/spaces/Kunbyte/ROSE
# %cd ROSE

# %% [markdown]
# # **Requirements**

# %%
# !pip install -r requirements.txt
# !pip install spaces
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# !pip install segment-anything
# !pip install omegaconf einops

# %% [markdown]
# # **Ffmpeg**

# %%
# !apt-get -y update
# !apt-get install -y libglib2.0-0 libgl1
# !apt-get install -y ffmpeg
# !apt-get install -y libavdevice-dev libavfilter-dev libavformat-dev libavcodec-dev libavutil-dev libswscale-dev libswresample-dev libavresample-dev
# !pip install --force-reinstall av

# %% [markdown]
# # **Main Code**

# %%
# !python app.py
